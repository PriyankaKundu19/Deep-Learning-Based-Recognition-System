# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaKundu19/Deep-Learning-Based-Recognition-System/blob/main/Priyanka's_MedicinalPlant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **DATASET**
# we have collected a dataset containing 2884 images of 15 medicinal plants (rich
# in therapeutic quality) and developed an automatic deep-learning-based recognition system.Our dataset name is MediPlantNet.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Methodology**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ⚡**APPLY MODEL**:
#
# 1.   CNN
#
# 1.   VGG16
# 2.   ResNet50
#
#
# 2.   MobileNet V3
#
#
# 1.   EfficientNet B5

# %% [markdown]
# # 🚀**CNN**
#
# ***Confusion Matrices***
#
# ![image.png](data:image/png;base64,...)
#
# ***Classification Reports***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🚀**VGG16**
#
# ***Confusion Matrices***
#
# ![image.png](data:image/png;base64,...)
#
# ***Classification Reports***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🚀**ResNet50**
#
# ***Confusion Matrices***
#
# ![image.png](data:image/png;base64,...)
#
# ***Classification Reports***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🚀**MobileNet V3**
#
# ***Confusion Matrices***
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ***Classification Reports***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🚀**EfficientNet B5**
#
# ***Confusion Matrices***
#
# ![image.png](data:image/png;base64,...)
#
#
# ***Classification Reports***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Visualizing Predictions Sample**
#
#
# ![Predicted_Class_VS_True_class.png](data:image/png;base64,...)
